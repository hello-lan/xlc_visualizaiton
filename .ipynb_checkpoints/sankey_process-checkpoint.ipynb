# %%
import pandas as pd

# %%
# df = pd.read_excel("transfer_out.xlsx")

# df = pd.read_excel("transfer_out_total.xlsx")
# df = pd.read_excel("transfer_out_chengdu.xlsx")

path ="transfer_out_hangzhou.xlsx"
path ="transfer_out_nanjing.xlsx"
path ="transfer_out_hefei.xlsx"
path ="transfer_out_wuhan.xlsx"
df = pd.read_excel(path)

# %%
df
# Out:
#    cate_1  cate_2           amt     ratio
# 0      其他      其他  4.236329e+07  0.011426
# 1      取款      取款  2.093884e+08  0.056477
# 2      消费      京东  1.325483e+07  0.003575
# 3      消费    其他消费  1.815960e+08  0.048981
# 4      消费      微信  9.106712e+07  0.024563
# 5      消费     支付宝  2.422049e+08  0.065328
# 6      消费      美团  1.541087e+06  0.000416
# 7      理财    他行理财  5.041305e+07  0.013598
# 8      理财    其他理财  2.227117e+08  0.060071
# 9      理财  天天基金理财  3.200155e+07  0.008632
# 10     理财    微信理财  1.394649e+07  0.003762
# 11     理财   支付宝理财  1.522841e+08  0.041075
# 12     理财    行内理财  1.321139e+08  0.035634
# 13     购房      购房  3.630942e+07  0.009794
# 14     转账   第三方转账  1.883415e+08  0.050800
# 15     转账    同行同名  1.697156e+08  0.045776
# 16     转账    同行异名  3.425598e+08  0.092397
# 17     转账    跨行同名  6.724061e+08  0.181364
# 18     转账    跨行异名  5.900534e+08  0.159152
# 19     还款      还款  3.232204e+08  0.087180

# %%
df_1 = df.groupby("cate_1", as_index=False)["ratio"].sum().rename(columns={"cate_1":"target", "ratio":"value"})
df_1["source"] = "总资金"

df_2 = df.rename(columns={"cate_1":"source", "cate_2":"target","ratio":"value"})[["source", "target","value"]]

# %%
df_1["level"] = 1
df_2["level"] = 2

df_link = pd.concat([df_1, df_2], axis=0)

# %%
#df_link.to_csv("transout_sankey.csv", index=False)

# %%
colors = { '支付宝理财': "#0066CC",
          '微信': "#00FF00",
          '其他消费': "#66FF00",
          '支付宝': "#3366FF",
          '跨行异名': "#6699CC",
          '微信理财': "#33FF33",
          '美团': "#FFA500",
          '同行同名': "#6B8E23",
          '总资金':"#0099CC",
          '他行理财': "#00CCCC",
          '取款': "#6699FF",
          '第三方转账': "#99CC66",
          '其他理财': "#9999CC",
          '跨行同名': "#99CC00",
          '其他': "#CC9966",
          '京东': "#99CC66",
          '天天基金理财': "#FF9999",
          '理财': "#669999",
          '同行异名': "#6699CC",
          '转账': "#FF9900",
          '行内理财': "#99CC99",
          '购房': "#CCCCFF",
          '还款': "#99CC66",
          '消费': "#33CC66",
         }

# %%
## 各个节点的值
pct_1 = df_1.groupby("source")["value"].sum().to_dict()
pct_2 = df_2.groupby("source")["value"].sum().to_dict()
pct_3 = df_2.query("source!=target").groupby("target")["value"].sum().to_dict()

pct = dict()
pct.update(pct_1)
pct.update(pct_2)
pct.update(pct_3)

total = sum(pct_2.values())
pct_new = {n:"{:.2f}%".format(100*(v/total)) if n != "总资金" else "100%" for n, v in pct.items()}


#  构造echart 桑吉图的节点
nodes_ = set(df_1[["source","target"]].values.reshape(-1).tolist()) | set(df_2[["source","target"]].values.reshape(-1).tolist())

nodes = [{"name":n,"itemStyle":{"color":colors[n]}, "value": pct_new[n]} for n in nodes_]

# %%
links = df_1.to_dict(orient="records")

links.extend(df_2.query("source!=target").to_dict(orient="records"))

# %%
data = {"links": links, "nodes":nodes}

# %%
data
# Out:
# {'links': [{'target': '其他',
#    'value': 0.0114264000951944,
#    'source': '总资金',
#    'level': 1},
#   {'target': '取款', 'value': 0.0564770829125374, 'source': '总资金', 'level': 1},
#   {'target': '消费', 'value': 0.14286311748746058, 'source': '总资金', 'level': 1},
#   {'target': '理财', 'value': 0.1627706051072925, 'source': '总资金', 'level': 1},
#   {'target': '购房', 'value': 0.00979352495211194, 'source': '总资金', 'level': 1},
#   {'target': '转账', 'value': 0.5294889471076886, 'source': '总资金', 'level': 1},
#   {'target': '还款', 'value': 0.0871803223377147, 'source': '总资金', 'level': 1},
#   {'source': '消费', 'target': '京东', 'value': 0.00357514596732287, 'level': 2},
#   {'source': '消费', 'target': '其他消费', 'value': 0.0489808145053509, 'level': 2},
#   {'source': '消费', 'target': '微信', 'value': 0.0245629941734571, 'level': 2},
#   {'source': '消费', 'target': '支付宝', 'value': 0.0653284945624211, 'level': 2},
#   {'source': '消费', 'target': '美团', 'value': 0.000415668278908626, 'level': 2},
#   {'source': '理财', 'target': '他行理财', 'value': 0.0135976130597345, 'level': 2},
#   {'source': '理财', 'target': '其他理财', 'value': 0.0600707205881635, 'level': 2},
#   {'source': '理财',
#    'target': '天天基金理财',
#    'value': 0.00863158888067479,
#    'level': 2},
#   {'source': '理财', 'target': '微信理财', 'value': 0.00376170526270859, 'level': 2},
#   {'source': '理财', 'target': '支付宝理财', 'value': 0.0410746811270039, 'level': 2},
#   {'source': '理财', 'target': '行内理财', 'value': 0.0356342961890072, 'level': 2},
#   {'source': '转账', 'target': '第三方转账', 'value': 0.0508002360779805, 'level': 2},
#   {'source': '转账', 'target': '同行同名', 'value': 0.0457763788784847, 'level': 2},
#   {'source': '转账', 'target': '同行异名', 'value': 0.0923966135417024, 'level': 2},
#   {'source': '转账', 'target': '跨行同名', 'value': 0.181364122490079, 'level': 2},
#   {'source': '转账', 'target': '跨行异名', 'value': 0.159151596119442, 'level': 2}],
#  'nodes': [{'name': '支付宝理财',
#    'itemStyle': {'color': '#0066CC'},
#    'value': '4.11%'},
#   {'name': '微信', 'itemStyle': {'color': '#00FF00'}, 'value': '2.46%'},
#   {'name': '其他消费', 'itemStyle': {'color': '#66FF00'}, 'value': '4.90%'},
#   {'name': '支付宝', 'itemStyle': {'color': '#3366FF'}, 'value': '6.53%'},
#   {'name': '第三方转账', 'itemStyle': {'color': '#99CC66'}, 'value': '5.08%'},
#   {'name': '跨行异名', 'itemStyle': {'color': '#6699CC'}, 'value': '15.92%'},
#   {'name': '微信理财', 'itemStyle': {'color': '#33FF33'}, 'value': '0.38%'},
#   {'name': '美团', 'itemStyle': {'color': '#FFA500'}, 'value': '0.04%'},
#   {'name': '同行同名', 'itemStyle': {'color': '#6B8E23'}, 'value': '4.58%'},
#   {'name': '总资金', 'itemStyle': {'color': '#0099CC'}, 'value': '100%'},
#   {'name': '他行理财', 'itemStyle': {'color': '#00CCCC'}, 'value': '1.36%'},
#   {'name': '取款', 'itemStyle': {'color': '#6699FF'}, 'value': '5.65%'},
#   {'name': '其他理财', 'itemStyle': {'color': '#9999CC'}, 'value': '6.01%'},
#   {'name': '跨行同名', 'itemStyle': {'color': '#99CC00'}, 'value': '18.14%'},
#   {'name': '其他', 'itemStyle': {'color': '#CC9966'}, 'value': '1.14%'},
#   {'name': '京东', 'itemStyle': {'color': '#99CC66'}, 'value': '0.36%'},
#   {'name': '天天基金理财', 'itemStyle': {'color': '#FF9999'}, 'value': '0.86%'},
#   {'name': '理财', 'itemStyle': {'color': '#669999'}, 'value': '16.28%'},
#   {'name': '同行异名', 'itemStyle': {'color': '#6699CC'}, 'value': '9.24%'},
#   {'name': '转账', 'itemStyle': {'color': '#FF9900'}, 'value': '52.95%'},
#   {'name': '行内理财', 'itemStyle': {'color': '#99CC99'}, 'value': '3.56%'},
#   {'name': '购房', 'itemStyle': {'color': '#CCCCFF'}, 'value': '0.98%'},
#   {'name': '还款', 'itemStyle': {'color': '#99CC66'}, 'value': '8.72%'},
#   {'name': '消费', 'itemStyle': {'color': '#33CC66'}, 'value': '14.29%'}]}

# %%
# import json
# with open("sankey.json", "w") as f:
#     json.dump(data, f)
